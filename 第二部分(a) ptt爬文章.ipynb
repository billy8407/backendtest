# %%
import requests
from bs4 import BeautifulSoup
url=input("請輸入任意看板網址來進行爬蟲")
x=int(input("請輸入您要爬幾頁的資料 ex:3  "))

#url="https://www.ptt.cc/bbs/Lifeismoney/index.html"
    
def get_all_href(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    results = soup.select("div.title")
    for item in results:
        a_item = item.select_one("a")
        if a_item:
            get_article_content(article_url='https://www.ptt.cc'+a_item.get('href'))
    print('------------------ next page ------------------')

def get_article_content(article_url):
    r = requests.get(article_url)
    soup = BeautifulSoup(r.text, "html.parser")
    print("=====================================================================")
    #print(soup)
    results = soup.select('span.article-meta-value')
    n=soup.select('#main-content')
    
    
        
        
    
    if results:
        print('作者:', results[0].text)
        print('看板:', results[1].text)
        print('標題:', results[2].text)
        print('時間:', results[3].text)    
    if n:
        print('內文:',n[0].text)
    
for page in range(1,x+1): 
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    btn = soup.select('div.btn-group > a')
    if btn:
        next_page_url = 'https://www.ptt.cc' + btn[3]['href']
        url = next_page_url
        print('page:', url)
        get_all_href(url = url)
# Out:
# 請輸入任意看板網址來進行爬蟲https://www.ptt.cc/bbs/Lifeismoney/index.html
# 請輸入您要爬幾頁的資料 ex:3  1
# page: https://www.ptt.cc/bbs/Lifeismoney/index2456.html
# ...
# 作者: eternalduck (鴨比)
# 看板: Lifeismoney
# 標題: [情報] 五月TTE台北旅展 開放免費索票了
# 時間: Mon Feb 25 22:48:33 2019
# 內文: 作者eternalduck (鴨比)看板Lifeismoney標題[情報] 五月TTE台北旅展 開放免費索票了時間Mon Feb 25 22:48:33 2019
# 今天在粉絲頁看到的
#
# https://www.facebook.com/120011791345977/posts/2973408222672972?sfns=mo
#
# 5/17-20夏季旅展官網已經可以預約免費門票了
#
# 這場比ITF小一點 但還是很大了 還是免費可加減看
#
# 開放到3/29  https://goo.gl/4Dsx4n
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 101.13.130.44
# ※ 文章網址: https://www.ptt.cc/bbs/Lifeismoney/M.1551106116.A.64D.html
# 推 ayumori     : 最近上聯都送票送很大 甚至展覽開始了也到處免費送 02/25 22:53
# 推 tingover    : 票不好賣吧 賺攤位費 02/25 23:51
# → s864372002  : 這是觀博啦 夏季是這個:http://ste.tw.tranews.com/ 02/26 00:49
# → cola0010    : 乾脆直接免費不就好了 02/26 02:50
# 推 shter       : 直接免費你不見得想去，拿了免費票就會想不去白不去 02/26 03:16
# 推 cckkyle     : 請問一下友台中的模鐵嗎? 02/26 09:29
# 推 lio293123   : S大的見解有道理 真厲害 02/26 17:37
# ...
